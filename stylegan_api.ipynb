# %%
# !git clone https://github.com/Vaibhav2711/stylegan
# Out:
# Cloning into 'stylegan'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 43 (delta 5), reused 43 (delta 5), pack-reused 0
# Unpacking objects: 100% (43/43), done.

# %%
# %cd stylegan
# Out:
# /content/stylegan

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !gdown --id 1Mq8jTkq3pTHsKeTk7IKhtd7rddW25x3W
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Mq8jTkq3pTHsKeTk7IKhtd7rddW25x3W
# To: /content/stylegan/karras2019stylegan-ffhq-1024x1024.pkl
# 325MB [00:05, 64.5MB/s]

# %%
# !pip install fastapi
# Out:
# ...
#      |████████████████████████████████| 51kB 4.3MB/s
# ...
#      |████████████████████████████████| 61kB 5.5MB/s
# ...
#      |████████████████████████████████| 10.1MB 15.0MB/s
# ...

# %%
# !pip install uvicorn
# Out:
# ...
#      |████████████████████████████████| 51kB 4.3MB/s
# ...
#      |████████████████████████████████| 61kB 5.5MB/s
# ...

# %%
# !pip install pyngrok
# Out:
# ...
#      |████████████████████████████████| 747kB 8.7MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.0.5-cp37-none-any.whl size=19246 sha256=7f7b5b1507d9f5ccd59e9514c1eb9ffefa77f65374835ac70c1b1d46d3bbc04d
#   Stored in directory: /root/.cache/pip/wheels/0c/13/64/5ebbcc22eaf53fdf5766b397c1fb17c83f5775fdccf0ea1b88
# Successfully built pyngrok
# ...

# %%
# !uvicorn main:app --reload
# Out:
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [523] using statreload
# WARNING:tensorflow:From ./dnnlib/tflib/tfutil.py:34: The name tf.Dimension is deprecated. Please use tf.compat.v1.Dimension instead.
#
# WARNING:tensorflow:From ./dnnlib/tflib/tfutil.py:74: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From ./dnnlib/tflib/tfutil.py:128: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# NgrokTunnel: "http://2dac34d278ca.ngrok.io" -> "http://localhost:8000"
# INFO:     Started server process [525]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     2405:201:5c08:cb30:84fa:287a:1758:47df:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     2405:201:5c08:cb30:84fa:287a:1758:47df:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# ...
